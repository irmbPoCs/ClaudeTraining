# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    model_score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": model_score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_account_id(arn):\n    match = re.search(r'^arn:aws:[^:]+:([^:]*):([^:]*):(.*)$', arn)\n    if match:\n        return match.group(2) if match.group(2) else None\n    return None\n\n# Test with the provided example\narn = 'arn:aws:s3:::my-bucket/path/to/object'\nprint(extract_account_id(arn))\n",
#     "test_case": {
#       "task": "Extract the AWS account ID from an ARN string like 'arn:aws:s3:::my-bucket/path/to/object'",
#       "format": "regex"
#     },
#     "score": 8.0,
#     "reasoning": "The solution is technically correct according to AWS ARN specifications. S3 ARNs legitimately have an empty account ID field (5th component), so the function correctly returns None for the provided example. However, the lack of documentation makes this behavior unclear, and there's no defensive programming for invalid inputs. For a production solution, input validation and clearer documentation would be important additions."
#   },
#   {
#     "output": "\nimport json\nimport sys\n\ndef parse_cloudformation_template(template_input):\n    \"\"\"Parse CloudFormation template and extract resource logical IDs and types\"\"\"\n    \n    if isinstance(template_input, str):\n        try:\n            template = json.loads(template_input)\n        except json.JSONDecodeError:\n            import yaml\n            template = yaml.safe_load(template_input)\n    else:\n        template = template_input\n    \n    resources = template.get('Resources', {})\n    \n    result = {}\n    for logical_id, resource_config in resources.items():\n        result[logical_id] = resource_config.get('Type', '')\n    \n    return result\n\nif __name__ == \"__main__\":\n    template_input = sys.stdin.read()\n    output = parse_cloudformation_template(template_input)\n    print(json.dumps(output, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and return a JSON object containing all resource logical IDs and their types",
#       "format": "json"
#     },
#     "score": 3.0,
#     "reasoning": "The solution correctly solves the core task of parsing CloudFormation templates and extracting resource IDs with types. The dual JSON/YAML support is a thoughtful addition. However, robustness is compromised by insufficient error handling - edge cases like invalid YAML syntax, missing Resources section, or resources without Type fields will cause failures or unexpected behavior. The code would benefit from explicit validation, better error messages, and proper module imports. For production use, these issues should be addressed."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if an AWS S3 bucket name follows naming conventions:\n    - Lowercase letters, numbers, and hyphens only\n    - 3-63 characters long\n    - No consecutive hyphens\n    - Cannot start or end with a hyphen\n    \"\"\"\n    # Check length\n    if not (3 <= len(bucket_name) <= 63):\n        return False\n    \n    # Check if lowercase and valid characters\n    if not re.match(r'^[a-z0-9\\-]+$', bucket_name):\n        return False\n    \n    # Check for consecutive hyphens\n    if '--' in bucket_name:\n        return False\n    \n    # Check if starts or ends with hyphen\n    if bucket_name.startswith('-') or bucket_name.endswith('-'):\n        return False\n    \n    return True\n\n\n# Test cases\ntest_cases = [\n    (\"my-bucket\", True),\n    (\"valid-bucket-name\", True),\n    (\"a-b\", False),  # Too short\n    (\"ab\", False),  # Too short\n    (\"abc\", True),  # Minimum valid length\n    (\"a\" * 63, True),  # Maximum valid length\n    (\"a\" * 64, False),  # Too long\n    (\"My-Bucket\", False),  # Contains uppercase\n    (\"my_bucket\", False),  # Contains underscore\n    (\"my--bucket\", False),  # Consecutive hyphens\n    (\"-mybucket\", False),  # Starts with hyphen\n    (\"mybucket-\", False),  # Ends with hyphen\n    (\"my.bucket\", False),  # Contains dot\n    (\"my-bucket123\", True),  # Valid with numbers\n]\n\nfor bucket_name, expected in test_cases:\n    result = validate_s3_bucket_name(bucket_name)\n    status = \"\u2713\" if result == expected else \"\u2717\"\n    print(f\"{status} {bucket_name}: {result} (expected {expected})\")\n",
#     "test_case": {
#       "task": "Write a Python function that validates if an AWS S3 bucket name follows naming conventions (lowercase, 3-63 characters, no consecutive hyphens)",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution demonstrates solid understanding of most AWS S3 bucket naming conventions and implements the core requirements effectively. The code is clean and readable with appropriate use of regex. However, there's a logical error in the test cases that would cause confusion, and it's missing some AWS-specific rules like IP address format validation. The lack of defensive programming for invalid input types is a minor but notable omission."
#   }
# ]
