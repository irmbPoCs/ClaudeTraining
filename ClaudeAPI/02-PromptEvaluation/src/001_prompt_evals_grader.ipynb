# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS CloudFormation Template Parser\n\nI'll help you create a solution to parse AWS CloudFormation templates and extract resource logical IDs.\n\n```python\nimport json\nimport yaml\nfrom typing import List, Dict, Any\n\nclass CloudFormationParser:\n    \"\"\"Parse AWS CloudFormation templates and extract resource logical IDs\"\"\"\n    \n    @staticmethod\n    def parse_template(template_content: str) -> Dict[str, Any]:\n        \"\"\"\n        Parse CloudFormation template (JSON or YAML format)\n        \n        Args:\n            template_content: String containing the template\n            \n        Returns:\n            Parsed template as dictionary\n        \"\"\"\n        # Try JSON first\n        try:\n            return json.loads(template_content)\n        except json.JSONDecodeError:\n            pass\n        \n        # Try YAML\n        try:\n            return yaml.safe_load(template_content)\n        except yaml.YAMLError as e:\n            raise ValueError(f\"Failed to parse template: {e}\")\n    \n    @staticmethod\n    def extract_resource_ids(template: Dict[str, Any]) -> List[str]:\n        \"\"\"\n        Extract all resource logical IDs from CloudFormation template\n        \n        Args:\n            template: Parsed CloudFormation template\n            \n        Returns:\n            List of resource logical IDs\n        \"\"\"\n        resources = template.get('Resources', {})\n        \n        if not isinstance(resources, dict):\n            raise ValueError(\"Resources section must be a dictionary\")\n        \n        return list(resources.keys())\n    \n    @staticmethod\n    def get_resources_with_details(template: Dict[str, Any]) -> Dict[str, Dict[str, Any]]:\n        \"\"\"\n        Get resources with their types and properties\n        \n        Args:\n            template: Parsed CloudFormation template\n            \n        Returns:\n            Dictionary with logical IDs as keys and resource details as values\n        \"\"\"\n        resources = template.get('Resources', {})\n        result = {}\n        \n        for logical_id, resource in resources.items():\n            result[logical_id] = {\n                'Type': resource.get('Type'),\n                'Properties': resource.get('Properties', {})\n            }\n        \n        return result\n\n\n# Example Usage\nif __name__ == \"__main__\":\n    \n    # Example CloudFormation template in JSON\n    template_json = \"\"\"\n    {\n        \"AWSTemplateFormatVersion\": \"2010-09-09\",\n        \"Description\": \"Sample CloudFormation Template\",\n        \"Resources\": {\n            \"MyS3Bucket\": {\n                \"Type\": \"AWS::S3::Bucket\",\n                \"Properties\": {\n                    \"BucketName\": \"my-bucket\"\n                }\n            },\n            \"MyEC2Instance\": {\n                \"Type\": \"AWS::EC2::Instance\",\n                \"Properties\": {\n                    \"ImageId\": \"ami-0c55b159cbfafe1f0\",\n                    \"InstanceType\": \"t2.micro\"\n                }\n            },\n            \"MyRDSDatabase\": {\n                \"Type\": \"AWS::RDS::DBInstance\",\n                \"Properties\": {\n                    \"DBInstanceIdentifier\": \"mydb\",\n                    \"Engine\": \"mysql\"\n                }\n            }\n        }\n    }\n    \"\"\"\n    \n    # Example CloudFormation template in YAML\n    template_yaml = \"\"\"\n    AWSTemplateFormatVersion: '2010-09-09'\n    Description: Sample CloudFormation Template\n    Resources:\n      MyS3Bucket:\n        Type: AWS::S3::Bucket\n        Properties:\n          BucketName: my-bucket\n      MyEC2Instance:\n        Type: AWS::EC2::Instance\n        Properties:\n          ImageId: ami-0c55b159cbfafe1f0\n          InstanceType: t2.micro\n      MyRDSDatabase:\n        Type: AWS::RDS::DBInstance\n        Properties:\n          DBInstanceIdentifier: mydb\n          Engine: mysql\n    \"\"\"\n    \n    parse ...
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates solid software engineering practices with good class structure and dual-format support. However, it is functionally incomplete - the example section doesn't actually run or demonstrate the parser working. Additionally, the error handling is minimal and doesn't account for malformed templates or edge cases that would be common in production AWS environments. The code would benefit from completion of the example section, more robust validation, and comprehensive error handling."
#   },
#   {
#     "output": "# S3 Read-Only Access Policy\n\nHere's a JSON policy document that grants read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:ListBucketVersions\",\n        \"s3:GetBucketLocation\",\n        \"s3:ListBucketMultipartUploads\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    }\n  ]\n}\n```\n\n## Key Components:\n\n| Component | Description |\n|-----------|-------------|\n| **GetObject** | Allows reading/downloading objects from the bucket |\n| **GetObjectVersion** | Allows reading specific object versions |\n| **GetObjectTagging** | Allows reading object tags |\n| **ListBucket** | Allows listing objects in the bucket |\n| **GetBucketVersioning** | Allows checking versioning status |\n| **GetBucketLocation** | Allows retrieving bucket region information |\n\n## Important Notes:\n\n- **Replace `my-bucket-name`** with your actual S3 bucket name\n- The `/*` suffix on the Resource ARN applies permissions to all objects within the bucket\n- The second statement allows bucket-level operations (without `/*`)\n- This policy denies write, delete, and administrative operations\n- Users can only read and list contents, not modify them\n\n## Usage:\n\nAttach this policy to an IAM user, role, or group using the AWS Console, AWS CLI, or SDK.",
#     "test_case": {
#       "task": "Create a JSON policy document that allows read-only access to a specific S3 bucket",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution provides a functional and well-documented read-only S3 policy with proper ARN structure and clear separation of concerns. The included actions appropriately cover most read-only scenarios. However, it omits commonly-needed read actions (ACL/policy inspection) and lacks guidance on the principle of least privilege, which could result in over-permissioning. The policy is production-ready but could be more tailored depending on actual requirements."
#   },
#   {
#     "output": "# AWS IAM Role ARN Regex Pattern\n\nHere's a comprehensive regex pattern to validate AWS IAM role ARNs:\n\n```regex\n^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$\n```\n\n## Explanation\n\n| Component | Pattern | Description |\n|-----------|---------|-------------|\n| **Start** | `^` | Beginning of string |\n| **Prefix** | `arn:aws:iam::` | Literal ARN prefix |\n| **Account ID** | `\\d{12}` | Exactly 12 digits |\n| **Resource Type** | `:role/` | Literal role designation |\n| **Role Name** | `[\\w+=,.@-]+` | 1+ alphanumeric, `+=,.@-` chars |\n| **End** | `$` | End of string |\n\n## Implementation Examples\n\n### Python\n```python\nimport re\n\npattern = r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$'\n\n# Valid examples\nvalid_arns = [\n    \"arn:aws:iam::123456789012:role/MyRole\",\n    \"arn:aws:iam::999999999999:role/service-role/MyServiceRole\",\n    \"arn:aws:iam::000000000000:role/my-role_name\",\n]\n\n# Invalid examples\ninvalid_arns = [\n    \"arn:aws:iam::12345678901:role/MyRole\",  # 11 digits\n    \"arn:aws:iam::123456789012:user/MyUser\",  # not a role\n    \"arn:aws:iam::123456789012:role/\",  # missing role name\n]\n\nfor arn in valid_arns:\n    assert re.match(pattern, arn), f\"Failed: {arn}\"\n    print(f\"\u2713 Valid: {arn}\")\n\nfor arn in invalid_arns:\n    assert not re.match(pattern, arn), f\"Failed: {arn}\"\n    print(f\"\u2717 Invalid: {arn}\")\n```\n\n### JavaScript\n```javascript\nconst pattern = /^arn:aws:iam::\\d{12}:role\\/[\\w+=,.@-]+$/;\n\nconst validArn = \"arn:aws:iam::123456789012:role/MyRole\";\nconsole.log(pattern.test(validArn)); // true\n```\n\n## Enhanced Pattern (with role path support)\n\nIf you want to support role paths like `role/path/to/role-name`:\n\n```regex\n^arn:aws:iam::\\d{12}:role(?:/[\\w+=,.@-]+)+$\n```\n\nThis allows one or more path segments separated by forward slashes.",
#     "test_case": {
#       "task": "Write a regex pattern to validate AWS IAM role ARNs in the format arn:aws:iam::account-id:role/role-name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution provides a functional regex pattern with good documentation and practical examples. However, it has a critical flaw in character class validation\u2014the pattern allows characters that AWS IAM role names don't actually support (like `+=,.@`). While the enhanced pattern addresses path support, the base pattern should handle this common case. The character class should be `[\\w-]` to match AWS documentation. Despite these issues, the solution demonstrates solid understanding of ARN structure and provides working code examples."
#   }
# ]
